# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1')
dataset.head()

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', header = None)
dataset.head()

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', header = 2)
dataset.head()

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', index_col='Title')
dataset.head()

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', usecols = ['Title', 'Genre1'])
dataset.head()

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', na_values = [''])
dataset.head()

# %%
#Escolha se deseja pular linhas em branco.
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', skip_blank_lines = False)
dataset.head()

# %%
#Opções de análise de dados.
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', skiprows = [1,2,3,7])
dataset.head()

# %%
#Pular linhas do rodapé ou final do arquivo.
dataset.tail(2)
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1',skipfooter=2 ,engine='python')
dataset.tail()

# %%
#Lendo o subconjunto de um arquivo ou um certo número de linhas.
dataset = pd.read_csv('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.csv', encoding = 'ISO-8859-1', nrows=100)
dataset.head()

# %% [markdown]
# # **#Leitura de dados de arquivos Excel.**

# %%
#Leitura de dados de várias planilhas.
dataset = pd.ExcelFile('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.xlsx')
dataset.sheet_names

# %%
dataset1 = dataset.parse('movies')
dataset2 = dataset.parse('by genre')
dataset1.head()

# %%
# Escolha de cabeçalho ou rótulos de coluna.
dataset = pd.read_excel('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.xlsx', sheet_name=1, header=3)
dataset.head()

# %%
# Sem header.
dataset = pd.read_excel('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.xlsx', sheet_name=1, header=None)
dataset.head()

# %%
#Pulando linhas no início.
dataset = pd.read_excel('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.xlsx', sheet_name=1, skiprows=7)
dataset.head()

# %%
#Pulando linhas no final.
dataset = pd.read_excel('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.xlsx', sheet_name=1, skipfooter=10)
dataset.head()

# %%
#Escolhendo colunas

df = pd.read_excel('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.xlsx', sheet_name=0, index_col='Title' )
df.head()

# %%
#Tratamento de dados perdidos durante a leitura.
df = pd.read_excel('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.xlsx', sheet_name=0, na_values=[''])
df.head()

# %% [markdown]
# # **Leitura de dados de outros formatos populares.**
# Também aprenderemos como ler dados do formato JSON, arquivos HTML e o conjunto de dados PICKLE e como ler dados de um banco de dados baseado em SQL

# %%
#Lendo dados JSON em pandas
dataset = pd.read_json('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.json', encoding = 'UTF-8')
dataset.head()

# %% [markdown]
# # **Trabalhando com dados em HTML**
# Temos os dados que extraímos do arquivo HTML em um formato tabular

# %%
dataset = pd.read_html('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.html')
dataset

# %% [markdown]
# # **Trabalhando um arquivo PICKLE**
# Usamos o método read_pickle para ler nosso arquivo PICKLE, conforme mostrado no código a seguir. Tal como acontece com outros formatos de dados, o pandas cria um DataFrame a partir dos dados lidos:

# %%
dataset = pd.read_pickle('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.p')
dataset.head()

# %% [markdown]
# # **Trabalhando com dados SQL**
# Aqui estaremos lendo dados SQL do popular navegador de banco de dados que é o ***SQLite***.

# %%
import sqlite3

conn = sqlite3.connect('/content/drive/MyDrive/Mastering Exploratory Analysis with Pandas by Harish Garg/Data/IMDB.sqlite')
dataset = pd.read_sql_query('SELECT * FROM IMDB;', conn)
dataset.head()

# %% [markdown]
# # **Trabalhando dados da área de transferência.**
# Para ler os dados da área de transferência, primeiro copie alguns dados. No exemplo a seguir, copiamos uma tabela de um conjunto de dados de filmes:

# %%
dataset = pd.read_clipboard()
dataset.head()
